# %% [markdown]
# ## 1 - Dataset Acquisition and Initial Setup
#
# In this first step, we are downloading the **FaceForensics++** dataset, the **c23** version, which corresponds to a moderate H.264 video compression (Constant Rate Factor 23).
#
# To streamline the acquisition process, we rely on the `kagglehub` library. This tool allows us to fetch the dataset directly from Kaggle and caches it locally.

# %%
import cv2
import glob
import kagglehub
import os
import pandas as pd
from pathlib import Path
from tqdm import tqdm

# %%
print("Starting the download of the FaceForensics++ (c23) dataset...")
print("Note: This might take a while the first time...")

dataset_path = kagglehub.dataset_download("xdxd003/ff-c23")
print("Download completed or loaded from chache")
print("Dataset path:", dataset_path)

folder_items = os.listdir(dataset_path)
print("Contents inside", dataset_path, ": ")
print('\n'.join([f"- {item}" for item in folder_items]))
# Out:
# Starting the download of the FaceForensics++ (c23) dataset...
# Note: This might take a while the first time...
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Download completed or loaded from chache
# Dataset path: /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1
# Contents inside /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1 :
# - FaceForensics++_C23

# %%
base_path = os.path.join(dataset_path, "FaceForensics++_C23")
folders = os.listdir(base_path)
print("Contents inside", base_path, ": ")
print('\n'.join([f"- {f}" for f in folders]))
# Out:
# Contents inside /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23 :
# - DeepFakeDetection
# - Deepfakes
# - original
# - FaceShifter
# - FaceSwap
# - csv
# - NeuralTextures
# - Face2Face

# %%
for folder in folders:
    folder_path = os.path.join(base_path, folder)

    try:
        files = [file for file in os.listdir(folder_path)]

        if files:
            print(f"{folder}: {files[0]}")
        else:
            print(f"{folder}: Zero .mp4 files founded")

    except FileNotFoundError:
        print(f"{folder}: folder not founded")
# Out:
# DeepFakeDetection: 02_15__walking_and_outside_surprised__MZWH8ATN.mp4
# Deepfakes: 475_265.mp4
# original: 578.mp4
# FaceShifter: 475_265.mp4
# FaceSwap: 475_265.mp4
# csv: NeuralTextures.csv
# NeuralTextures: 475_265.mp4
# Face2Face: 475_265.mp4

# %% [markdown]
# ## 2 - Pandas DataFrame
#
# This section creates a single pandas DataFrame containing all videos from the dataset.
#
# Columns:
# - `video`: filename
# - `label`: 0 = real, 1 = fake
# - `method`: manipulation type or "original"
# - `target`: ID of the person being manipulated for fakes or identity of original
# - `source`: ID of the source video for fakes or identity of original
# - `sequence`: the specific name of the video sequence or scene recorded
# - `experiment id`: an 8-character identifier used to distinguish multiple recordings of the same actor pairings
# - `path`: full path to the video file

# %%
data = []

for folder in folders:
    folder_path = os.path.join(base_path, folder)

    if not os.path.exists(folder_path):
        continue

    if folder == "original":
        for video in os.listdir(folder_path):
            id = f"classic_{video.replace('.mp4', '')}"
            data.append({
                "video": video,
                "label": 0,
                "method": "original",
                "target": id,
                "source": id,
                "sequence": None,
                "exp_id": None,
                "path": os.path.join(folder_path, video)
            })

    elif folder == "DeepFakeDetection":
        for video in os.listdir(folder_path):
            if not video.endswith(".mp4"): continue

            name = video.replace(".mp4", "")
            parts = name.split("__")

            if len(parts) >= 3:
                actors = parts[0]
                sequence = parts[1]
                exp_id = parts[2]

                actors_parts = actors.split("_")
                if len(actors_parts) >= 2:
                    target = f"dfd_{actors_parts[0]}"
                    source = f"dfd_{actors_parts[1]}"
            else:
                continue

            data.append({
                "video": video,
                "label": 1,
                "method": folder,
                "target": target,
                "source": source,
                "sequence": sequence,
                "exp_id": exp_id,
                "path": os.path.join(folder_path, video)
            })

    else:
        for video in os.listdir(folder_path):
            if not video.endswith(".mp4"): continue

            name = video.replace(".mp4", "")
            parts = name.split("_")
            if len(parts) >= 2:
                target = f"classic_{parts[0]}"
                source = f"classic_{parts[1]}"
            else:
                continue

            data.append({
                "video": video,
                "label": 1,
                "method": folder,
                "target": target,
                "source": source,
                "sequence": None,
                "exp_id": None,
                "path": os.path.join(folder_path, video)
            })
    
videos = pd.DataFrame(data)

pd.set_option('display.max_colwidth', None)
display(videos.sample(15))
# Out:
#                                  video  label             method       target  \
# 5689                       840_800.mp4      1     NeuralTextures  classic_840
# 4685                       846_845.mp4      1           FaceSwap  classic_846
# 3465                       365_307.mp4      1        FaceShifter  classic_365
# 1408                       688_645.mp4      1          Deepfakes  classic_688
# 6486                       687_615.mp4      1          Face2Face  classic_687
# 3499                       225_151.mp4      1        FaceShifter  classic_225
# 6024                       734_699.mp4      1          Face2Face  classic_734
# 6779                       599_585.mp4      1          Face2Face  classic_599
# 1771                       082_103.mp4      1          Deepfakes  classic_082
# 1331                       783_916.mp4      1          Deepfakes  classic_783
# 4909                       166_167.mp4      1           FaceSwap  classic_166
# 2355                           652.mp4      0           original  classic_652
# 4891                       585_599.mp4      1           FaceSwap  classic_585
# 37    19_23__kitchen_pan__WHQ1229T.mp4      1  DeepFakeDetection       dfd_19
# 4437                       972_718.mp4      1           FaceSwap  classic_972
#
#            source     sequence    exp_id  \
# 5689  classic_800         None      None
# 4685  classic_845         None      None
# 3465  classic_307         None      None
# 1408  classic_645         None      None
# 6486  classic_615         None      None
# 3499  classic_151         None      None
# 6024  classic_699         None      None
# 6779  classic_585         None      None
# 1771  classic_103         None      None
# 1331  classic_916         None      None
# 4909  classic_167         None      None
# 2355  classic_652         None      None
# 4891  classic_599         None      None
# 37         dfd_23  kitchen_pan  WHQ1229T
# 4437  classic_718         None      None
#
#                                                                                                                                              path
# 5689                          /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/NeuralTextures/840_800.mp4
# 4685                                /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceSwap/846_845.mp4
# 3465                             /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceShifter/365_307.mp4
# 1408                               /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Deepfakes/688_645.mp4
# 6486                               /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Face2Face/687_615.mp4
# 3499                             /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceShifter/225_151.mp4
# 6024                               /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Face2Face/734_699.mp4
# 6779                               /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Face2Face/599_585.mp4
# 1771                               /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Deepfakes/082_103.mp4
# 1331                               /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Deepfakes/783_916.mp4
# 4909                                /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceSwap/166_167.mp4
# 2355                                    /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/original/652.mp4
# 4891                                /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceSwap/585_599.mp4
# 37    /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/DeepFakeDetection/19_23__kitchen_pan__WHQ1229T.mp4
# 4437                                /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceSwap/972_718.mp4

# %% [markdown]
# ### 2.1 - Sanity Check
#
# Quick checks to ensure the dataset is loaded correctly:
#
# - Total number of videos
# - Distribution of real vs fake videos
# - Distribution of manipulation methods
# - Number of unique target and source IDs

# %%
print("Total videos:", len(videos))
print("\nLabel distribution (fake/real):")
print(videos["label"].value_counts())
print("\nMethod distribution:")
print(videos["method"].value_counts())
print("\nTarget and Source identical for all 'original' videos:", (videos[videos['method'] == 'original']['target'] == videos[videos['method'] == 'original']['source']).all())
print("\nTarget unique number (identity):", videos["target"].nunique())
print("\nSource unique number:", videos["source"].nunique())
# Out:
# Total videos: 7000
#
# Label distribution (fake/real):
# label
# 1    6000
# 0    1000
# Name: count, dtype: int64
#
# Method distribution:
# method
# DeepFakeDetection    1000
# Deepfakes            1000
# original             1000
# FaceShifter          1000
# FaceSwap             1000
# NeuralTextures       1000
# Face2Face            1000
# Name: count, dtype: int64
#
# Target and Source identical for all 'original' videos: True
#
# Target unique number (identity): 1028
#
# Source unique number: 1028

# %% [markdown]
# ### 2.2  - Distribution of Fake Videos per Target
#
# Analyzes how many fake videos exist per target identity to identify if some identities dominate the fake samples

# %%
fake_df = videos[videos["label"] == 1]
per_target = fake_df.groupby("target").size()
print("\n--- FAKE PER TARGET STATISTICS ---")
print(per_target.describe())
# Out:
# --- FAKE PER TARGET STATISTICS ---
# count    1028.000000
# mean        5.836576
# std         5.854495
# min         5.000000
# 25%         5.000000
# 50%         5.000000
# 75%         5.000000
# max        76.000000
# dtype: float64

# %% [markdown]
# ### 2.3 - Distribution Of Methods per Target (Check Variability):
#
# Creates a pivot table showing how many videos of each manipulation method exist per target to verify that each identity has a representative set of manipulation methods and to detect identities with too few or missing manipulation types

# %%
pivot = pd.pivot_table(
    videos,
    index="target",
    columns="method",
    values="video",
    aggfunc="count",
    fill_value=0
)

print("\n--- METHOD DISTRIBUTION PER TARGET STATISTICS ---")
display(pivot.sample(20))
# Out:
# --- METHOD DISTRIBUTION PER TARGET STATISTICS ---
# method       DeepFakeDetection  Deepfakes  Face2Face  FaceShifter  FaceSwap  \
# target
# classic_513                  0          1          1            1         1
# classic_788                  0          1          1            1         1
# classic_931                  0          1          1            1         1
# classic_149                  0          1          1            1         1
# classic_981                  0          1          1            1         1
# classic_027                  0          1          1            1         1
# classic_203                  0          1          1            1         1
# classic_559                  0          1          1            1         1
# classic_848                  0          1          1            1         1
# dfd_06                      52          0          0            0         0
# classic_586                  0          1          1            1         1
# classic_900                  0          1          1            1         1
# classic_515                  0          1          1            1         1
# classic_653                  0          1          1            1         1
# classic_809                  0          1          1            1         1
# classic_245                  0          1          1            1         1
# classic_314                  0          1          1            1         1
# classic_361                  0          1          1            1         1
# classic_782                  0          1          1            1         1
# classic_385                  0          1          1            1         1
#
# method       NeuralTextures  original
# target
# classic_513               1         1
# classic_788               1         1
# classic_931               1         1
# classic_149               1         1
# classic_981               1         1
# classic_027               1         1
# classic_203               1         1
# classic_559               1         1
# classic_848               1         1
# dfd_06                    0         0
# classic_586               1         1
# classic_900               1         1
# classic_515               1         1
# classic_653               1         1
# classic_809               1         1
# classic_245               1         1
# classic_314               1         1
# classic_361               1         1
# classic_782               1         1
# classic_385               1         1

# %% [markdown]
# ### 2.4 - Check Label Balance
#
# Checks the ratio of real to fake videos across the entire dataset to understand dataset imbalance

# %%
print("Normalize label ditribution:")
print(videos["label"].value_counts(normalize=True))
# Out:
# Normalize label ditribution:
# label
# 1    0.857143
# 0    0.142857
# Name: proportion, dtype: float64

# %% [markdown]
# ### Dataset Observations
#
# - **Total videos:** 7,000 in total, with 6,000 fake and 1,000 real videos. This presents a strong class imbalance (~6:1)
# - **Target distribution is NOT uniform:** While the *median* is 5 fake videos per target, the dataset is heavily skewed by the `DeepFakeDetection` (DFD) subset. Because DFD relies on a small pool of professional actors filmed in multiple scenarios, some target identities appear in up to **76 fake videos**.
# - **Manipulation methods:** The methods are perfectly balanced. There are exactly 1,000 videos for each of the 6 manipulation techniques (`Deepfakes`, `Face2Face`, `FaceSwap`, `NeuralTextures`, `FaceShifter`, `DeepFakeDetection`), plus the 1,000 `original` unmanipulated videos.
# - **Target and source identities:** There are **2,028** unique target identities and **1,028** unique source identities. The "extra" 28 identities (beyond the base 1,000 subjects) belong to the hired actors from the Google DFD subset.

# %% [markdown]
# ## 3 - Metadata Extraction (OpenCV)
#
# In this cell, we use **OpenCV (`cv2`)** to iterate through our entire dataset of 7,000 videos and extract key metadata:
# - `total_frames`
# - `fps`
# - `duration_sec`
# - `resolution`

# %%
tqdm.pandas(desc="Extracting video metadata")

videos_cv2 = videos.copy()

"""
Opens a video file momentarily just to read its metadata properties,
then closes it immediately to save memory.
"""
def get_video_metadata(video_path):
    try:
        cap = cv2.VideoCapture(video_path)

        if not cap.isOpened():
            return pd.Series([None, None, None, None])
    
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = cap.get(cv2.CAP_PROP_FPS)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        duration = total_frames / fps
        
        cap.release()

        return pd.Series([total_frames, fps, duration, f"{width}x{height}"])
    
    except Exception as e:
        return pd.Series([None, None, None, None])

print("Scanning all 7000 videos to extract physical metadata. This might take 1-3 minutes...")
videos[['total_frames', 'fps', 'duration_sec', 'resolution']] = videos['path'].progress_apply(get_video_metadata)

print("\nMetadata extraction complete!")
# Out:
# Scanning all 7000 videos to extract physical metadata. This might take 1-3 minutes...
# Extracting video metadata: 100%|██████████| 7000/7000 [00:37<00:00, 188.08it/s]
# Metadata extraction complete!

# %%
print("\n--- VIDEO DURATION STATISTICS (in seconds) ---")
print(videos['duration_sec'].describe())

print("\n--- VIDEO FRAMES STATISTICS ---")
print(videos['total_frames'].describe())

display(videos.sample(20))
# Out:
# --- VIDEO DURATION STATISTICS (in seconds) ---
# count    7000.000000
# mean       19.325502
# std         9.536235
# min         0.208333
# 25%        12.833333
# 50%        16.500000
# 75%        22.320000
# max        72.560000
# Name: duration_sec, dtype: float64
#
# --- VIDEO FRAMES STATISTICS ---
# count    7000.000000
# mean      511.797143
# std       229.865219
# min         5.000000
# 25%       346.000000
# 50%       444.000000
# 75%       594.000000
# max      1814.000000
# Name: total_frames, dtype: float64
#                                          video  label             method  \
# 2756                                   099.mp4      0           original
# 4981                               092_098.mp4      1           FaceSwap
# 1099                               403_497.mp4      1          Deepfakes
# 1202                               102_114.mp4      1          Deepfakes
# 5893                               146_256.mp4      1     NeuralTextures
# 355       09_26__exit_phone_room__XXGYLT82.mp4      1  DeepFakeDetection
# 4166                               280_249.mp4      1           FaceSwap
# 5286                               145_299.mp4      1     NeuralTextures
# 3365                               313_283.mp4      1        FaceShifter
# 2296                                   453.mp4      0           original
# 2963                                   825.mp4      0           original
# 4292                               827_817.mp4      1           FaceSwap
# 3516                               253_183.mp4      1        FaceShifter
# 6095                               165_137.mp4      1          Face2Face
# 6396                               289_228.mp4      1          Face2Face
# 292           26_18__kitchen_pan__C9VUQS9O.mp4      1  DeepFakeDetection
# 5656                               990_008.mp4      1     NeuralTextures
# 709       18_14__exit_phone_room__0YRBHIKG.mp4      1  DeepFakeDetection
# 826   02_06__talking_angry_couch__MKZTXQ2T.mp4      1  DeepFakeDetection
# 6376                               182_242.mp4      1          Face2Face
#
#            target       source             sequence    exp_id  \
# 2756  classic_099  classic_099                 None      None
# 4981  classic_092  classic_098                 None      None
# 1099  classic_403  classic_497                 None      None
# 1202  classic_102  classic_114                 None      None
# 5893  classic_146  classic_256                 None      None
# 355        dfd_09       dfd_26      exit_phone_room  XXGYLT82
# 4166  classic_280  classic_249                 None      None
# 5286  classic_145  classic_299                 None      None
# 3365  classic_313  classic_283                 None      None
# 2296  classic_453  classic_453                 None      None
# 2963  classic_825  classic_825                 None      None
# 4292  classic_827  classic_817                 None      None
# 3516  classic_253  classic_183                 None      None
# 6095  classic_165  classic_137                 None      None
# 6396  classic_289  classic_228                 None      None
# 292        dfd_26       dfd_18          kitchen_pan  C9VUQS9O
# 5656  classic_990  classic_008                 None      None
# 709        dfd_18       dfd_14      exit_phone_room  0YRBHIKG
# 826        dfd_02       dfd_06  talking_angry_couch  MKZTXQ2T
# 6376  classic_182  classic_242                 None      None
#
#                                                                                                                                                      path  \
# 2756                                            /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/original/099.mp4
# 4981                                        /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceSwap/092_098.mp4
# 1099                                       /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Deepfakes/403_497.mp4
# 1202                                       /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Deepfakes/102_114.mp4
# 5893                                  /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/NeuralTextures/146_256.mp4
# 355       /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/DeepFakeDetection/09_26__exit_phone_room__XXGYLT82.mp4
# 4166                                        /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceSwap/280_249.mp4
# 5286                                  /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/NeuralTextures/145_299.mp4
# 3365                                     /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceShifter/313_283.mp4
# 2296                                            /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/original/453.mp4
# 2963                                            /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/original/825.mp4
# 4292                                        /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceSwap/827_817.mp4
# 3516                                     /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/FaceShifter/253_183.mp4
# 6095                                       /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Face2Face/165_137.mp4
# 6396                                       /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Face2Face/289_228.mp4
# 292           /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/DeepFakeDetection/26_18__kitchen_pan__C9VUQS9O.mp4
# 5656                                  /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/NeuralTextures/990_008.mp4
# 709       /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/DeepFakeDetection/18_14__exit_phone_room__0YRBHIKG.mp4
# 826   /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/DeepFakeDetection/02_06__talking_angry_couch__MKZTXQ2T.mp4
# 6376                                       /Users/luciapola/.cache/kagglehub/datasets/xdxd003/ff-c23/versions/1/FaceForensics++_C23/Face2Face/182_242.mp4
#
#       total_frames   fps  duration_sec resolution
# 2756           613  25.0     24.520000  1920x1080
# 4981           299  25.0     11.960000    720x480
# 1099           707  30.0     23.566667    272x480
# 1202           389  25.0     15.560000    720x480
# 5893           546  24.0     22.750000   1280x720
# 355            337  24.0     14.041667  1920x1080
# 4166           606  30.0     20.200000    854x480
# 5286           314  15.0     20.933333    576x480
# 3365           481  30.0     16.033333    654x480
# 2296           645  30.0     21.500000   1280x718
# 2963           547  25.0     21.880000    854x480
# 4292           311  30.0     10.366667    640x480
# 3516           501  30.0     16.700000   1280x720
# 6095           606  25.0     24.240000    640x480
# 6396           556  25.0     22.240000    704x480
# 292            694  24.0     28.916667  1920x1080
# 5656           305  25.0     12.200000    832x480
# 709            387  24.0     16.125000  1920x1080
# 826           1279  24.0     53.291667  1920x1080
# 6376           331  30.0     11.033333   1280x720

# %%
print("Creation of the videos copy and extraction of extended data from the CSV…")

videos_csv = videos.copy()

metadata_csv_path = os.path.join(base_path, "csv", "FF++_Metadata.csv")
ff_metadata = pd.read_csv(metadata_csv_path)

ff_metadata['csv_method'] = ff_metadata['File Path'].apply(lambda x: Path(x).parts[0])
ff_metadata['csv_video'] = ff_metadata['File Path'].apply(lambda x: Path(x).name)
ff_metadata = ff_metadata.drop_duplicates(subset=['csv_method', 'csv_video'])

ff_metadata['csv_res_string'] = ff_metadata['Width'].astype(str) + "x" + ff_metadata['Height'].astype(str)

videos_csv = videos_csv.merge(
    ff_metadata[['csv_method', 'csv_video', 'Frame Count', 'csv_res_string']], 
    left_on=['method', 'video'], 
    right_on=['csv_method', 'csv_video'], 
    how='left'
)

videos_csv = videos_csv.rename(columns={
    'Frame Count': 'csv_frames',
    'csv_res_string': 'csv_resolution'
})
videos_csv = videos_csv.drop(columns=['csv_method', 'csv_video'])

print("\nCSV extraction complete!")
print(f"Rows: {len(videos_csv)}")
# Out:
# Creation of the videos copy and extraction of extended data from the CSV…
#
# CSV extraction complete!
# Rows: 7000

# %% [markdown]
# ## 5 - Data Integrity Verification (OpenCV vs. CSV)
#
# To ensure absolute data integrity, we cross-reference the video properties (frame count and resolution) dynamically extracted via OpenCV with the official metadata provided by the dataset authors.

# %%
print("--- VERIFICATION: OpenCV vs. CSV ---")

#Comparison DataFrame
comparison_df = pd.DataFrame({
    'video': videos['video'],
    'method': videos['method'],
    'opencv_frames': videos['total_frames'],
    'csv_frames': videos_csv['csv_frames'],
    'opencv_resolution': videos['resolution'],
    'csv_resolution': videos_csv['csv_resolution']
})

mask_frames = comparison_df['opencv_frames'] != comparison_df['csv_frames']
mask_res = comparison_df['opencv_resolution'] != comparison_df['csv_resolution']

mismatched_videos = comparison_df[(mask_frames | mask_res)].dropna()

if mismatched_videos.empty:
    print("OK: Frame counts and Resolution (Width x Height) match perfectly across all 7000 videos.")
else:
    print(f"WARNING: Found discrepancies in {len(mismatched_videos)} videos.")
    display(mismatched_videos.sample(10))
# Out:
# --- VERIFICATION: OpenCV vs. CSV ---
# OK: Frame counts and Resolution (Width x Height) match perfectly across all 7000 videos.

# %% [markdown]
# ### Metadata Observations
#
# The comparison reveals two crucial details about the dataset. First, the frame counts match perfectly between OpenCV and the CSV, confirming that the physical video files are intact and uncorrupted. However, there is a consistent discrepancy in the resolutions: the official CSV reports the original 16:9 rectangular formats (e.g., `1920x1080`), while OpenCV reveals that the actual files are 1:1 perfect squares (e.g., `1080x1080`).

# %% [markdown]
# ## 6 - Saving Processed Data
#
# To conclude this notebook, we save the fully cleaned and processed DataFrame to a local CSV file (`./processed_videos/dataframe_videos`). This ensures our prepared dataset is safely stored and ready to be directly loaded into the next notebook of our pipeline without needing to re-run the preprocessing steps.

# %%
print("--- SAVING DATAFRAME ---")

output_dir = "./processed_videos"
os.makedirs(output_dir, exist_ok=True)

save_path = os.path.join(output_dir, "dataframe_videos")
videos.to_csv(save_path, index=False)

print(f"Data succesfully saved to: {save_path}")
# Out:
# --- SAVING DATAFRAME ---
# Data succesfully saved to: ./processed_videos/dataframe_videos
